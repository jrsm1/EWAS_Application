# %%
import matplotlib.pyplot as plt
#import plotly.plotly as py
import numpy as np
import pandas as pd

# %%
# Load Dummy Data (CSV File)
# This file's index is the Row number from MSexcel
data_read = pd.read_csv(r'G:\Team Drives\CAPSTONE TEAM FOLDER\Implementation\Application\Data Processing\Random_Dummy_Data_v1.csv')
data_read.tail(5)
# Out:
#          INDEX  S1  S2  S3  S4
# 174995  174996   3  -1  -9  13
# 174996  174997 -13  -6  14   6
# 174997  174998   8  -4   1   5
# 174998  174999   8  -8  13  -4
# 174999  175000  -7 -10 -13   9

# %%
s1 = []
for row in data_read['S1']: # each row is a list
    s1.append(row)
    
s1
# Out:
# [1,
#  6,
#  -3,
#  -10,
#  -3,
#  14,
#  -14,
#  15,
#  -10,
#  -11,
#  -10,
#  6,
#  10,
#  -6,
#  -11,
#  14,
#  -4,
#  3,
#  -11,
#  -12,
#  -12,
#  -11,
#  -1,
#  -5,
#  -14,
#  -5,
#  -12,
#  11,
#  -2,
#  15,
#  -7,
#  4,
#  -2,
#  12,
#  -13,
#  6,
#  2,
#  8,
#  4,
#  1,
#  -12,
#  -2,
#  2,
#  -4,
#  -3,
#  -7,
#  -7,
#  10,
#  9,
#  -8,
#  2,
#  1,
#  8,
#  2,
#  13,
#  5,
#  -7,
#  -11,
#  -13,
#  12,
#  0,
#  9,
#  15,
#  0,
#  -4,
#  9,
#  -4,
#  1,
#  -15,
#  10,
#  -1,
#  13,
#  6,
#  -14,
#  -9,
#  -14,
#  -13,
#  10,
#  15,
#  4,
#  -14,
#  -5,
#  5,
#  -11,
#  3,
#  15,
#  -7,
#  9,
#  -8,
#  -2,
#  3,
#  -2,
#  2,
#  12,
#  -14,
#  -2,
#  10,
#  4,
#  10,
#  12,
#  10,
#  -4,
#  15,
#  10,
#  11,
#  -5,
#  12,
#  -14,
#  11,
#  5,
#  -12,
#  12,
#  -1,
#  -9,
#  4,
#  14,
#  4,
#  5,
#  8,
#  8,
#  14,
#  -11,
#  14,
#  -10,
#  -3,
#  2,
#  10,
#  6,
#  -6,
#  -4,
#  14,
#  1,
#  -11,
#  0,
#  14,
#  -4,
#  -4,
#  -12,
#  14,
#  7,
#  2,
#  13,
#  -1,
#  9,
# ...

# %%
fourier = np.fft.fft(s1)

fourier
# Out:
# array([4745.        +5.33110795e-14j, 3162.16299491+6.51971881e+03j,
#         545.87375255-3.42824102e+03j, ...,  760.60182962-1.95950451e+02j,
#         545.87375255+3.42824102e+03j, 3162.16299491-6.51971881e+03j])

# %%
len(fourier)
# Out:
# 175000

# %%
import matplotlib.figure as fig

freq = np.fft.fftfreq(len(results))

plt.plot(freq, fourier.real**2 + fourier.imag**2)
plt.show()

# %%
fourier.shape
# Out:
# (175000,)

# %%
freq.shape
# Out:
# (175000,)

# %%
freq
# Out:
# array([ 0.00000000e+00,  5.71428571e-06,  1.14285714e-05, ...,
#        -1.71428571e-05, -1.14285714e-05, -5.71428571e-06])

# %% [markdown]
# # EXAMPLE

# %%
>>> import numpy as np
>>> import matplotlib.pyplot as plt

>>> N = 256
>>> t = np.arange(N)

>>> m = 4
>>> nu = float(m)/N
>>> f = np.sin(2*np.pi*nu*t)
>>> ft = np.fft.fft(f)
>>> freq = np.fft.fftfreq(N)
>>> plt.plot(freq, ft.real**2 + ft.imag**2)
>>> plt.show()

# %%
type(ft)
# Out:
# numpy.ndarray

# %%
type(fourier)
# Out:
# numpy.ndarray
