# %%
import numpy as np
import scipy.io as spio
import pandas as pd 

data_read = pd.read_csv(r'C:\Users\drgdm\OneDrive - University of Puerto Rico\Universidad\Clases\Capstone Proyect\Project\Application\Random_Dummy_Data_v1.csv')

result = []
for row in data_read['S1']: # each row is a list
    result.append(row)
    
result
# Out:
# [1,
#  6,
#  -3,
#  -10,
#  -3,
#  14,
#  -14,
#  15,
#  -10,
#  -11,
#  -10,
#  6,
#  10,
#  -6,
#  -11,
#  14,
#  -4,
#  3,
#  -11,
#  -12,
#  -12,
#  -11,
#  -1,
#  -5,
#  -14,
#  -5,
#  -12,
#  11,
#  -2,
#  15,
#  -7,
#  4,
#  -2,
#  12,
#  -13,
#  6,
#  2,
#  8,
#  4,
#  1,
#  -12,
#  -2,
#  2,
#  -4,
#  -3,
#  -7,
#  -7,
#  10,
#  9,
#  -8,
#  2,
#  1,
#  8,
#  2,
#  13,
#  5,
#  -7,
#  -11,
#  -13,
#  12,
#  0,
#  9,
#  15,
#  0,
#  -4,
#  9,
#  -4,
#  1,
#  -15,
#  10,
#  -1,
#  13,
#  6,
#  -14,
#  -9,
#  -14,
#  -13,
#  10,
#  15,
#  4,
#  -14,
#  -5,
#  5,
#  -11,
#  3,
#  15,
#  -7,
#  9,
#  -8,
#  -2,
#  3,
#  -2,
#  2,
#  12,
#  -14,
#  -2,
#  10,
#  4,
#  10,
#  12,
#  10,
#  -4,
#  15,
#  10,
#  11,
#  -5,
#  12,
#  -14,
#  11,
#  5,
#  -12,
#  12,
#  -1,
#  -9,
#  4,
#  14,
#  4,
#  5,
#  8,
#  8,
#  14,
#  -11,
#  14,
#  -10,
#  -3,
#  2,
#  10,
#  6,
#  -6,
#  -4,
#  14,
#  1,
#  -11,
#  0,
#  14,
#  -4,
#  -4,
#  -12,
#  14,
#  7,
#  2,
#  13,
#  -1,
#  9,
#  11,
#  -1,
#  2,
#  13,
#  14,
#  10,
#  12,
#  -2,
#  -5,
#  6,
#  14,
#  -6,
#  8,
#  6,
#  -15,
#  -2,
#  13,
#  10,
#  -7,
#  -7,
#  2,
#  12,
#  -3,
#  6,
#  -12,
#  -1,
#  8,
#  8,
#  7,
#  -1,
#  15,
#  2,
#  15,
#  7,
#  5,
#  12,
#  -14,
#  8,
#  3,
#  0,
#  3,
#  7,
#  13,
#  4,
#  14,
#  -5,
#  -8,
#  -13,
#  -8,
#  12,
#  -9,
#  7,
#  -15,
#  8,
#  15,
#  3,
#  -15,
#  -2,
#  -8,
#  3,
#  -10,
#  -3,
#  -11,
#  -10,
#  -4,
#  10,
#  15,
#  2,
#  9,
#  -11,
#  -7,
#  -13,
#  -6,
#  -7,
#  -6,
#  -4,
#  15,
#  8,
#  -12,
#  2,
#  2,
#  -4,
#  -12,
#  2,
#  5,
#  -8,
#  5,
#  -5,
#  -1,
#  -1,
#  -9,
#  -4,
#  3,
#  -14,
#  14,
#  10,
#  2,
#  -12,
#  4,
#  -11,
#  -13,
#  8,
#  10,
#  -1,
#  12,
#  10,
#  6,
#  -5,
#  -12,
#  -5,
#  2,
#  9,
#  -14,
#  -7,
#  10,
#  5,
#  3,
#  -5,
#  -13,
#  -11,
#  5,
#  -8,
#  4,
#  13,
#  8,
#  -7,
#  4,
#  5,
#  10,
#  -2,
#  6,
#  8,
#  4,
#  13,
#  8,
#  -12,
#  3,
#  -1,
#  8,
#  13,
#  -7,
#  -13,
#  -4,
#  -1,
#  1,
#  7,
#  -11,
#  5,
#  8,
#  11,
#  -7,
#  11,
#  11,
#  -13,
#  6,
#  11,
#  -12,
#  2,
#  -7,
#  14,
#  10,
#  14,
#  -13,
#  0,
#  -3,
#  -14,
#  1,
#  8,
#  -12,
#  10,
#  -8,
#  -12,
#  -10,
#  10,
#  2,
#  -1,
#  -7,
#  -1,
#  14,
#  -8,
#  2,
#  -11,
#  0,
#  13,
#  4,
#  -12,
#  -12,
#  -1,
#  11,
#  5,
#  -12,
#  -7,
#  6,
#  13,
#  6,
#  -5,
#  9,
#  0,
#  2,
#  -4,
#  -6,
#  -10,
#  2,
#  15,
#  -11,
#  12,
#  -13,
#  -6,
#  0,
#  -4,
#  -2,
#  -3,
#  -15,
#  -9,
#  -2,
#  -8,
#  10,
#  3,
#  3,
#  -14,
#  3,
#  -6,
#  9,
#  6,
#  5,
#  10,
#  -10,
#  9,
#  9,
#  6,
#  8,
#  11,
#  7,
#  -11,
#  8,
#  -2,
#  0,
#  -5,
#  12,
#  1,
#  3,
#  -1,
#  6,
#  9,
#  14,
#  8,
#  1,
#  -15,
#  -2,
#  5,
#  9,
#  -9,
#  -6,
#  -14,
#  -10,
#  13,
#  -13,
#  9,
#  2,
#  -8,
#  -5,
#  14,
#  -5,
#  15,
#  4,
#  15,
#  -7,
#  -15,
#  -11,
#  -13,
#  -5,
#  -1,
#  -3,
#  12,
#  2,
#  -2,
#  4,
#  -9,
#  13,
#  13,
#  2,
#  -1,
#  0,
#  0,
#  4,
#  15,
#  -14,
#  7,
#  -5,
#  8,
#  14,
#  -3,
#  -11,
#  -4,
#  -4,
#  2,
#  -9,
#  -9,
#  -8,
#  0,
#  -8,
#  -12,
#  10,
#  1,
#  -7,
#  -10,
#  7,
#  14,
#  15,
#  -7,
#  11,
#  -4,
#  3,
#  10,
#  -12,
#  11,
#  -11,
#  -4,
#  6,
#  14,
#  -11,
#  -12,
#  -9,
#  -2,
#  -14,
#  -10,
#  -9,
#  1,
#  7,
#  -9,
#  -2,
#  6,
#  14,
#  -7,
#  -4,
#  5,
#  12,
#  15,
#  -15,
#  -13,
#  15,
#  7,
#  7,
#  6,
#  -12,
#  4,
#  11,
#  8,
#  14,
#  6,
#  6,
#  13,
#  5,
#  -7,
#  5,
#  -1,
#  -14,
#  7,
#  4,
#  -10,
#  -8,
#  0,
#  10,
#  0,
#  -8,
#  0,
#  8,
#  5,
#  -11,
#  -2,
#  14,
#  14,
#  -4,
#  14,
#  -15,
#  9,
#  -12,
#  -11,
#  -10,
#  15,
#  -10,
#  14,
#  -12,
#  9,
#  -4,
#  11,
#  -10,
#  5,
#  -3,
#  -11,
#  -4,
#  9,
#  13,
#  -6,
#  -9,
#  -9,
#  -3,
#  -6,
#  15,
#  -14,
#  8,
#  13,
#  -12,
#  2,
#  7,
#  5,
#  -15,
#  -2,
#  8,
#  -11,
#  -11,
#  -11,
#  -10,
#  -13,
#  2,
#  -15,
#  -11,
#  -10,
#  -11,
#  11,
#  8,
#  -6,
#  -11,
#  -3,
#  15,
#  -10,
#  15,
#  -4,
#  -11,
#  9,
#  -12,
#  -2,
#  8,
#  -15,
#  -13,
#  12,
#  2,
#  7,
#  7,
#  -14,
#  -6,
#  -11,
#  15,
#  -9,
#  10,
#  9,
#  1,
#  -9,
#  15,
#  3,
#  -5,
#  12,
#  1,
#  -6,
#  8,
#  -10,
#  12,
#  -9,
#  -3,
#  -13,
#  6,
#  12,
#  4,
#  10,
#  -4,
#  4,
#  7,
#  10,
#  -2,
#  6,
#  12,
#  -15,
#  -6,
#  7,
#  -9,
#  -11,
#  10,
#  -2,
#  -13,
#  -4,
#  12,
#  11,
#  -10,
#  1,
#  -12,
#  4,
#  -1,
#  -3,
#  9,
#  9,
#  13,
#  13,
#  -2,
#  -5,
#  -6,
#  3,
#  6,
#  11,
#  -9,
#  1,
#  -4,
#  -7,
#  4,
#  -8,
#  4,
#  -10,
#  4,
#  7,
#  -1,
#  6,
#  7,
#  -2,
#  -5,
#  -6,
#  14,
#  14,
#  -15,
#  2,
#  -2,
#  0,
#  -3,
#  -9,
#  12,
#  -12,
#  -15,
#  -9,
#  -10,
#  -6,
#  -15,
#  1,
#  0,
#  -15,
#  -5,
#  12,
#  -5,
#  -3,
#  7,
#  4,
#  -10,
#  -13,
#  -15,
#  -14,
#  -10,
#  -5,
#  -14,
#  5,
#  3,
#  2,
#  0,
#  -1,
#  -8,
#  10,
#  -2,
#  2,
#  -11,
#  3,
#  -1,
#  3,
#  -11,
#  -6,
#  5,
#  2,
#  -3,
#  -2,
#  -15,
#  -9,
#  -15,
#  15,
#  -4,
#  -14,
#  -13,
#  -2,
#  -11,
#  2,
#  8,
#  -7,
#  -8,
#  1,
#  -14,
#  4,
#  -4,
#  10,
#  0,
#  11,
#  14,
#  12,
#  -14,
#  4,
#  11,
#  1,
#  -2,
#  -1,
#  8,
#  -7,
#  11,
#  5,
#  -11,
#  -2,
#  3,
#  1,
#  11,
#  5,
#  -12,
#  12,
#  3,
#  2,
#  12,
#  -8,
#  -2,
#  11,
#  4,
#  11,
#  -13,
#  4,
#  13,
#  6,
#  -5,
#  -4,
#  6,
#  13,
#  5,
#  -8,
#  -9,
#  14,
#  -1,
#  5,
#  -15,
#  -4,
#  15,
#  12,
#  -14,
#  -13,
#  -15,
#  -8,
#  -15,
#  -7,
#  8,
#  7,
#  -2,
#  8,
#  4,
#  -7,
#  -11,
#  -4,
#  -4,
#  15,
#  -7,
#  -10,
#  4,
#  4,
#  0,
#  -11,
#  -6,
#  -14,
#  15,
#  2,
#  8,
#  -14,
#  -10,
#  -7,
#  -3,
#  -2,
#  -8,
#  11,
#  2,
#  0,
#  -6,
#  2,
#  -14,
#  -1,
#  -10,
#  8,
#  -3,
#  -9,
#  7,
#  -15,
#  -10,
#  6,
#  -12,
#  -14,
#  -12,
#  -4,
#  12,
#  -14,
#  13,
#  -14,
#  10,
#  -2,
#  -10,
#  12,
#  -1,
#  -5,
#  -2,
#  -3,
#  12,
#  14,
#  -13,
#  13,
#  -2,
#  2,
#  -10,
#  -3,
#  -7,
#  8,
#  -5,
#  -2,
#  -6,
#  15,
#  5,
#  5,
#  4,
#  -1,
#  5,
#  -10,
#  1,
#  -10,
#  1,
#  -8,
#  6,
#  -3,
#  -1,
#  15,
#  7,
#  -10,
#  10,
#  -12,
#  -13,
#  -13,
#  -14,
#  -6,
#  14,
#  -12,
#  11,
#  -15,
#  -6,
#  9,
#  -14,
#  -6,
#  5,
#  -9,
#  -7,
#  12,
#  8,
#  12,
#  -7,
#  -12,
#  -4,
#  4,
#  14,
#  0,
#  15,
#  8,
#  -2,
#  -4,
#  1,
#  -14,
#  -8,
#  -4,
#  -15,
#  -10,
#  15,
#  -14,
#  1,
#  -12,
#  -13,
#  8,
#  15,
#  7,
#  -4,
#  -9,
#  -10,
#  11,
#  10,
#  -9,
#  13,
#  -3,
#  12,
#  -5,
#  2,
#  10,
#  -12,
#  12,
#  8,
#  1,
#  7,
#  11,
#  7,
#  -14,
#  -15,
#  5,
#  9,
#  14,
#  3,
#  -10,
#  -13,
#  5,
#  -5,
#  5,
#  -15,
#  -12,
#  -2,
#  -3,
#  1,
#  -3,
#  -1,
#  14,
#  -7,
#  15,
#  9,
#  -15,
#  -14,
#  -5,
#  -1,
#  -9,
#  10,
#  -10,
#  -6,
#  -3,
#  15,
#  -13,
#  3,
#  13,
#  4,
#  -9,
#  13,
#  -14,
#  -15,
#  -3,
#  -11,
#  -4,
#  -7,
#  -9,
#  3,
#  0,
#  3,
#  10,
#  -14,
#  15,
#  4,
#  5,
#  -10,
#  10,
#  -5,
#  -1,
#  5,
#  -9,
#  10,
#  2,
#  -2,
#  12,
#  10,
#  9,
#  12,
#  -9,
#  2,
#  1,
#  ...]

# %%
spio.savemat('C:\Users\drgdm\OneDrive - University of Puerto Rico\Universidad\Clases\Capstone Proyect\Project\Application\export_to_matlab.mat', mdict={'arr' : result})
# Out:
#   File "<ipython-input-4-809b54a8c1c2>", line 1
#     spio.savemat('C:\Users\drgdm\OneDrive - University of Puerto Rico\Universidad\Clases\Capstone Proyect\Project\Application\export_to_matlab.mat', mdict={'arr' : result})
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
